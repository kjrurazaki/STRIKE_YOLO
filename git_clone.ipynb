# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
! ls
# Out:
# gdrive	sample_data

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/STRIKE_YOLO_DRIVE
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/STRIKE_YOLO_DRIVE

# %%
! git clone https://github.com/kjrurazaki/STRIKE_YOLO.git

# %%
# %cd ./STRIKE_YOLO
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/STRIKE_YOLO_DRIVE/STRIKE_YOLO

# %%
! git pull
# Out:
# Already up to date.
